# %%
import pandas as pd

url = "https://projects.fivethirtyeight.com/nba-model/nba_elo_latest.csv"
df=pd.read_csv(url)
display(df.columns)
# Out:
# Index(['date', 'season', 'neutral', 'playoff', 'team1', 'team2', 'elo1_pre',
#        'elo2_pre', 'elo_prob1', 'elo_prob2', 'elo1_post', 'elo2_post',
#        'carm-elo1_pre', 'carm-elo2_pre', 'carm-elo_prob1', 'carm-elo_prob2',
#        'carm-elo1_post', 'carm-elo2_post', 'raptor1_pre', 'raptor2_pre',
#        'raptor_prob1', 'raptor_prob2', 'score1', 'score2', 'quality',
#        'importance', 'total_rating'],
#       dtype='object')

# %%
display(df[df['date'] == '2022-11-18'])
# Out:
#            date  season  neutral  playoff team1 team2     elo1_pre  \
# 223  2022-11-18    2023        0      NaN   WAS   MIA  1456.411746
# 224  2022-11-18    2023        0      NaN   PHI   MIL  1576.898839
# 225  2022-11-18    2023        0      NaN   CLE   CHO  1539.103911
# 226  2022-11-18    2023        0      NaN   MEM   OKC  1587.070853
# 227  2022-11-18    2023        0      NaN   HOU   IND  1348.821019
# 228  2022-11-18    2023        0      NaN   CHI   ORL  1455.408504
# 229  2022-11-18    2023        0      NaN   DAL   DEN  1564.282972
# 230  2022-11-18    2023        0      NaN   NOP   BOS  1569.949294
# 231  2022-11-18    2023        0      NaN   UTA   PHO  1569.276180
# 232  2022-11-18    2023        0      NaN   GSW   NYK  1586.621598
# 233  2022-11-18    2023        0      NaN   LAL   DET  1404.345291
#
#         elo2_pre  elo_prob1  elo_prob2  ...  carm-elo2_post  raptor1_pre  \
# 223  1566.267296   0.485821   0.514179  ...             NaN  1440.556082
# ...
